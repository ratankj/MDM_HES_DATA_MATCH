# %%
import pandas as pd
import numpy as np
import os
import sys
from colorama import Fore, Back, Style
from datetime import datetime, timedelta
pd.set_option('display.max_columns', None)

# %%
ASSEST_SB =  pd.read_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\INPUT FOLDER\ASSET_INITIATION_INVENTORY_SB.csv")
ASSEST_NB = pd.read_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\INPUT FOLDER\ASSET_INITIATION_INVENTORY_NB.csv")
INFRA_SB = pd.read_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\INPUT FOLDER\Infrastructure_Devices_SB.csv",sep=';')
INFRA_NB = pd.read_csv( r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\INPUT FOLDER\Infrastructure_Devices_NB.csv",sep=';')
METER_STATUS_NB = pd.read_csv( r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\INPUT FOLDER\METER_STATUS_NB.csv")
METER_STATUS_SB = pd.read_csv( r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\INPUT FOLDER\METER_STATUS_SB.csv")

# %%
ASSEST_NB = ASSEST_NB.astype(str)
ASSEST_NB.columns = ASSEST_NB.columns.str.upper()
ASSEST_NB = ASSEST_NB.apply(lambda x: x.str.strip() if x.dtype == 'O' else x)
ASSEST_NB.columns = ASSEST_NB.columns.str.strip()



ASSEST_SB = ASSEST_SB.astype(str)
ASSEST_SB.columns = ASSEST_SB.columns.str.upper()
ASSEST_SB = ASSEST_SB.apply(lambda x: x.str.strip() if x.dtype == 'O' else x)
ASSEST_SB.columns = ASSEST_SB.columns.str.strip()
#-------------------------------------------------------------------------------------------

# %%
ASSEST_NB.head(1)
# Out:
#     METERNUMBER MFG_SERIAL_NUM           UDC_ID  \
# 0  GOEGP4968974      GP4968974  404759210464692
#
#                                 NETWORK_ID INSTALLATIONNUMBER   STATUS  \
# 0  2001:4490:0800:6073:0000:0000:0000:0001    MUZW-2290805636  Retired
#
#            INSERT_TIME DECODE(D.ORG_ID,52,'SBPDCL',102,'NBPDCL')
# 0  9/2/2019 1:07:37 AM                                    NBPDCL

# %%
# rename the column name

ASSEST_NB.rename(
    columns = {"METERNUMBER":"METERNUMBER_NB","MFG_SERIAL_NUM": "MFG_SERIAL_NUM_NB",
    "UDC_ID":"UDC_ID_NB","NETWORK_ID":"NETWORK_ID_NB",
    "INSTALLATIONNUMBER":"INSTALLATIONNUMBER_NB","STATUS":"STATUS_NB","INSERT_TIME":"INSERT_TIME_NB",
    "DECODE(D.ORG_ID,52,'SBPDCL',102,'NBPDCL')":"UTILITY_NB"},inplace=True
)



#-----------------------------------------------------------------




ASSEST_SB.rename(
    columns = {"METERNUMBER":"METERNUMBER_SB","MFG_SERIAL_NUM": "MFG_SERIAL_NUM_SB",
    "UDC_ID":"UDC_ID_SB","NETWORK_ID":"NETWORK_ID_SB",
    "INSTALLATIONNUMBER":"INSTALLATIONNUMBER_SB","STATUS":"STATUS_SB","INSERT_TIME":"INSERT_TIME_SB",
    "DECODE(D.ORG_ID,52,'SBPDCL',102,'NBPDCL')":"UTILITY_SB"},inplace=True
)

# %%
ASSEST_SB.head(1)
# Out:
#   METERNUMBER_SB MFG_SERIAL_NUM_SB        UDC_ID_SB  \
# 0   GOEGP4970294         GP4970294  404759210464358
#
#                              NETWORK_ID_SB INSTALLATIONNUMBER_SB   STATUS_SB  \
# 0  2001:4490:0800:5F25:0000:0000:0000:0001                   nan  Meter Shop
#
#         INSERT_TIME_SB UTILITY_SB
# 0  8/7/2019 1:26:44 PM     SBPDCL

# %%
ASSEST_NB['METERNUMBER_NB'] = ASSEST_NB['METERNUMBER_NB'].apply(lambda x: x.strip())
ASSEST_NB['MFG_SERIAL_NUM_NB'] = ASSEST_NB['MFG_SERIAL_NUM_NB'].apply(lambda x: x.strip())
ASSEST_NB['UDC_ID_NB'] = ASSEST_NB['UDC_ID_NB'].apply(lambda x: x.strip())
ASSEST_NB['NETWORK_ID_NB'] = ASSEST_NB['NETWORK_ID_NB'].apply(lambda x: x.strip())
ASSEST_NB['INSTALLATIONNUMBER_NB'] = ASSEST_NB['INSTALLATIONNUMBER_NB'].apply(lambda x: x.strip())
ASSEST_NB['STATUS_NB'] = ASSEST_NB['STATUS_NB'].apply(lambda x: x.strip())
ASSEST_NB['INSERT_TIME_NB'] = ASSEST_NB['INSERT_TIME_NB'].apply(lambda x: x.strip())
ASSEST_NB['UTILITY_NB'] = ASSEST_NB['UTILITY_NB'].apply(lambda x: x.strip())
#ASSEST_NB['METERNUMBER_NB'] = ASSEST_NB['METERNUMBER_NB'].apply(lambda x: x.strip())

print("assest Nb is done")



#  assest sb data 



ASSEST_SB['METERNUMBER_SB'] = ASSEST_SB['METERNUMBER_SB'].apply(lambda x: x.strip())
ASSEST_SB['MFG_SERIAL_NUM_SB'] = ASSEST_SB['MFG_SERIAL_NUM_SB'].apply(lambda x: x.strip())
ASSEST_SB['UDC_ID_SB'] = ASSEST_SB['UDC_ID_SB'].apply(lambda x: x.strip())
ASSEST_SB['NETWORK_ID_SB'] = ASSEST_SB['NETWORK_ID_SB'].apply(lambda x: x.strip())
ASSEST_SB['INSTALLATIONNUMBER_SB'] = ASSEST_SB['INSTALLATIONNUMBER_SB'].apply(lambda x: x.strip())
ASSEST_SB['STATUS_SB'] = ASSEST_SB['STATUS_SB'].apply(lambda x: x.strip())
ASSEST_SB['INSERT_TIME_SB'] = ASSEST_SB['INSERT_TIME_SB'].apply(lambda x: x.strip())
ASSEST_SB['UTILITY_SB'] = ASSEST_SB['UTILITY_SB'].apply(lambda x: x.strip())


print("assest Sb is done")
# Out:
# assest Nb is done
# assest Sb is done

# %%
ASSEST_NB.head()
# Out:
#   METERNUMBER_NB MFG_SERIAL_NUM_NB        UDC_ID_NB  \
# 0   GOEGP4968974         GP4968974  404759210464692
# 1   GOEGP4881969         GP4881969  404751250450510
# 2   GOEGP4881776         GP4881776  404751250009815
# 3   GOEGP4967107         GP4967107  404751250461212
# 4   GOEGP4880200         GP4880200  404751250470195
#
#                              NETWORK_ID_NB INSTALLATIONNUMBER_NB   STATUS_NB  \
# 0  2001:4490:0800:6073:0000:0000:0000:0001       MUZW-2290805636     Retired
# 1  2001:4490:0800:A41A:0000:0000:0000:0001            DALGND-816   Installed
# 2  fd00:0000:0800:E2CF:0000:0000:0000:0001            BRUBR-7529   Installed
# 3  2001:4490:0800:C6D4:0000:0000:0000:0001            DALGND-833   Installed
# 4  2001:4490:0800:CAA6:0000:0000:0000:0001                   nan  Meter Shop
#
#         INSERT_TIME_NB UTILITY_NB
# 0  9/2/2019 1:07:37 AM     NBPDCL
# 1  9/9/2019 1:01:27 AM     NBPDCL
# 2  9/9/2019 1:01:28 AM     NBPDCL
# 3  9/9/2019 1:01:29 AM     NBPDCL
# ...

# %% [markdown]
# #### METERNUMBER_NB  &  MFG_SERIAL_NUM_NB  : -   is not same
# #### METERNUMBER_SB  &  MFG_SERIAL_NUM_SB  : -   is not same

# %%
ASSEST_NB[ASSEST_NB['METERNUMBER_NB'].str[3:]!=ASSEST_NB['MFG_SERIAL_NUM_NB']]
# Out:
#         METERNUMBER_NB MFG_SERIAL_NUM_NB        UDC_ID_NB  \
# 27996     GOEGP7505514         GP7430333  404751250624075
# 76617    ﻿GOEGP4875734         GP4875734              nan
# 94382   LNTLTLT0690717         LT0690717  405856706692242
# 145855  LNTLTLT0085831         LT0085831              nan
# 181331    GOEGP7501388         GP7430334  404751250624074
# 196639  LNTLTLT0129262         LT0129262              nan
# 204346   ﻿GOEGP1025800         GP1025800              nan
# 204406    GOEGP5968449               nan              nan
# 220919  LNTLTLT0174521         LT0174521  405856706113267
# 273879  LNTLTLT0143605         LT0143605              nan
# 329648  LNTLTLT0160195         LT0160195  405856706310683
# 332042   ﻿GOEGP4876920         GP4876920              nan
# 375502  LNTLTLT0171228         LT0171228              nan
# 502865  LNTLTLT0109546         LT0109546              nan
# 579088  LNTLTLT0166555         LT0166555              nan
# ...

# %%
ASSEST_NB.shape
# Out:
# (816257, 8)

# %%
# Custom function to update meter numbers
def update_meter_number(meter_number):
    if meter_number.startswith('GP') or meter_number.startswith('GL'):
        return 'GOE' + meter_number
    elif meter_number.startswith('LT'):
        return 'LNT' + meter_number
    else:
        return meter_number

# Apply the custom function to each element in the 'METER NO.' column
ASSEST_NB['METER_NO_NB'] = ASSEST_NB['MFG_SERIAL_NUM_NB'].apply(update_meter_number)
ASSEST_SB['METER_NO_SB'] = ASSEST_SB['MFG_SERIAL_NUM_SB'].apply(update_meter_number)

# %% [markdown]
# # DATA DUPLICACY IN NB

# %%
# duplicacy on METER NO


ASSEST_NB_METER_NO_DUPLICATED = ASSEST_NB[ASSEST_NB.duplicated(subset=['MFG_SERIAL_NUM_NB'],keep=False)].sort_values(by=['MFG_SERIAL_NUM_NB'],ascending=True)
ASSEST_NB_METER_NO_DUPLICATED.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\OUTPUT FOLDER MDM\ASSEST_NB_METER_NO_DUPLICATED.csv")


# duplicacy on IP

ASSEST_NB_IP_DUPLICATED = ASSEST_NB[(ASSEST_NB.duplicated(subset=['NETWORK_ID_NB'],keep=False)) & (ASSEST_NB['NETWORK_ID_NB']!='nan')].sort_values(by='NETWORK_ID_NB',ascending=True)
ASSEST_NB_IP_DUPLICATED.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\OUTPUT FOLDER MDM\ASSEST_NB_IP_DUPLICATED.csv")

# DUPLICACY ON INSTALLATION NO

ASSEST_NB_INSTALLATION_DUPLICATED = ASSEST_NB[(ASSEST_NB.duplicated(subset=['INSTALLATIONNUMBER_NB'],keep=False)) & (ASSEST_NB['INSTALLATIONNUMBER_NB']!='nan')].sort_values(by=['INSTALLATIONNUMBER_NB'],ascending=False)
ASSEST_NB_INSTALLATION_DUPLICATED.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\OUTPUT FOLDER MDM\ASSEST_NB_INSTALLATION_DUPLICATED.csv")

# %%
# Out:
#        METERNUMBER_NB MFG_SERIAL_NUM_NB        UDC_ID_NB  \
# 516802   GOEGL8548353         GL8548353  405856706536765
# 101977   GOEGL8548353         GL8548353  405856706536765
# 750486   GOEGL8548408         GL8548408  405856706891833
# 317246   GOEGL8548408         GL8548408  405856706891833
# 355146   GOEGL8548429         GL8548429  405856706891688
# ...               ...               ...              ...
# 500498   LNTLT8040763         LT8040763  405856707400178
# 551354   LNTLT8040846         LT8040846  405856707400059
# 168885   LNTLT8040846         LT8040846  405856706772112
# 550493   LNTLT8041357         LT8041357  405856706905617
# 677841   LNTLT8041357         LT8041357  405856707402921
#
#                                   NETWORK_ID_NB INSTALLATIONNUMBER_NB  \
# 516802  2405:0203:0528:DC24:0000:0000:0000:0010            5004017369
# 101977  2405:0203:0528:DC24:0000:0000:0000:0010            5003906341
# ...

# %% [markdown]
# # DATA DUPLICACY IN SB

# %%
# duplicacy on METER NO


ASSEST_SB_METER_NO_DUPLICATED = ASSEST_SB[ASSEST_SB.duplicated(subset=['MFG_SERIAL_NUM_SB'],keep=False)].sort_values(by=['MFG_SERIAL_NUM_SB'],ascending=True)
ASSEST_SB_METER_NO_DUPLICATED.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\OUTPUT FOLDER MDM\ASSEST_SB_METER_NO_DUPLICATED.csv")

# duplicacy on IP

ASSEST_SB_IP_DUPLICATED = ASSEST_SB[(ASSEST_SB.duplicated(subset=['NETWORK_ID_SB'],keep=False)) & (ASSEST_SB['NETWORK_ID_SB']!='nan')].sort_values(by='NETWORK_ID_SB',ascending=True)
ASSEST_SB_IP_DUPLICATED.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\OUTPUT FOLDER MDM\ASSEST_SB_IP_DUPLICATED.csv")


# DUPLICACY ON INSTALLATION NO

ASSEST_SB_INSTALLATION_DUPLICATED = ASSEST_SB[(ASSEST_SB.duplicated(subset=['INSTALLATIONNUMBER_SB'],keep=False)) & (ASSEST_SB['INSTALLATIONNUMBER_SB']!='nan')].sort_values(by=['INSTALLATIONNUMBER_SB'],ascending=False)
ASSEST_SB_INSTALLATION_DUPLICATED.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\OUTPUT FOLDER MDM\ASSEST_SB_INSTALLATION_DUPLICATED.csv")

# %%
ASSEST_SB_METER_NO_DUPLICATED.head()
# Out:
#        METERNUMBER_SB MFG_SERIAL_NUM_SB        UDC_ID_SB  \
# 513915   GOEGL8548300         GL8548300  405856707172350
# 248749   GOEGL8548300         GL8548300  405856706536659
# 477210   GOEGL8548303         GL8548303  405856706536685
# 974015   GOEGL8548303         GL8548303  405856707299383
# 544052   GOEGL8548303         GL8548303  405856706536685
#
#                                   NETWORK_ID_SB INSTALLATIONNUMBER_SB  \
# 513915  2405:0203:0532:43AE:0000:0000:0000:0010            5001970345
# 248749  2405:0203:0528:DBEF:0000:0000:0000:0010            5001970345
# 477210  2405:0203:0528:DBF2:0000:0000:0000:0010            5004056701
# 974015  2405:0203:0531:9328:0000:0000:0000:0010            5004056701
# 544052  2405:0203:0528:DBF2:0000:0000:0000:0010            5002973847
#
#           STATUS_SB       INSERT_TIME_SB UTILITY_SB   METER_NO_SB
# 513915  Refurbished  5/4/2022 1:04:08 PM     SBPDCL  GOEGL8548300
# 248749  Refurbished  5/4/2022 1:04:08 PM     SBPDCL  GOEGL8548300
# ...

# %%
ASSEST_NB.head(1)
# Out:
#   METERNUMBER_NB MFG_SERIAL_NUM_NB        UDC_ID_NB  \
# 0   GOEGP4968974         GP4968974  404759210464692
#
#                              NETWORK_ID_NB INSTALLATIONNUMBER_NB STATUS_NB  \
# 0  2001:4490:0800:6073:0000:0000:0000:0001       MUZW-2290805636   Retired
#
#         INSERT_TIME_NB UTILITY_NB   METER_NO_NB
# 0  9/2/2019 1:07:37 AM     NBPDCL  GOEGP4968974

# %%
ASSEST_SB.head(1)
# Out:
#   METERNUMBER_SB MFG_SERIAL_NUM_SB        UDC_ID_SB  \
# 0   GOEGP4970294         GP4970294  404759210464358
#
#                              NETWORK_ID_SB INSTALLATIONNUMBER_SB   STATUS_SB  \
# 0  2001:4490:0800:5F25:0000:0000:0000:0001                   nan  Meter Shop
#
#         INSERT_TIME_SB UTILITY_SB   METER_NO_SB
# 0  8/7/2019 1:26:44 PM     SBPDCL  GOEGP4970294

# %%
CZXVBGF FD
# Out:
#   Cell In[42], line 1
#     CZXVBGF FD
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # merge nb and sb file

# %%
# JOIN ON   METER NO.

MDM_NB_SB_DATA_METER_NO = pd.merge(ASSEST_NB, ASSEST_SB, left_on=['METERNUMBER_NB'], right_on=['METERNUMBER_SB'], how='inner')
MDM_NB_SB_DATA_METER_NO.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\OUTPUT FOLDER HES\MDM_NB_SB_DATA_METER_NO.csv")


# join on 

MDM_NB_SB_DATA_SERIAL_NO = pd.merge(ASSEST_NB, ASSEST_SB, left_on=['MFG_SERIAL_NUM_NB'], right_on=['MFG_SERIAL_NUM_SB'], how='inner')
MDM_NB_SB_DATA_SERIAL_NO.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\OUTPUT FOLDER HES\MDM_NB_SB_DATA_SERIAL_NO.csv")


# JOIN ON INSTALLATION FILE

HES_NB_SB_DATA_INSTALLATION_NO = pd.merge(INFRA_NB_COMM_DATA, INFRA_SB_COMM_DATA, left_on=['UTILITYSITEID_NB'], right_on=['UTILITYSITEID_SB'], how='inner')
HES_NB_SB_DATA_INSTALLATION_NO.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\OUTPUT FOLDER HES\HES_NB_SB_DATA_INSTALLATION_NO.csv")


# JOIN ON IP DATA

MDM_NB_SB_DATA_IP = pd.merge(ASSEST_NB, ASSEST_SB, left_on=['NETWORK_ID_NB'], right_on=['NETWORK_ID_NB'], how='inner')
MDM_NB_SB_DATA_IP=HES_NB_SB_DATA_IP[(HES_NB_SB_DATA_IP['IP_NB']==HES_NB_SB_DATA_IP['IP_SB']) & (HES_NB_SB_DATA_IP['IP_NB']!='nan')  &  (HES_NB_SB_DATA_IP['IP_SB']!='nan') ]
MDM_NB_SB_DATA_IP.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\OUTPUT FOLDER HES\MDM_NB_SB_DATA_IP.csv")


# JOIN ON METER AND INSTALLATION DATA

HES_NB_SB_DATA_METER_AND_IP = pd.merge(INFRA_NB_COMM_DATA, INFRA_SB_COMM_DATA, left_on=['UTILITYDEVICEID_NB','IP_NB'], right_on=['UTILITYDEVICEID_SB','IP_SB'], how='inner')
HES_NB_SB_DATA_METER_AND_IP.to_csv(r"C:\Users\Ratan Kumar Jha\Desktop\hes_mdm\OUTPUT FOLDER HES\HES_NB_SB_DATA_METER_AND_IP.csv")

# %%
from colorama import Fore, Back, Style

# Print highlighted text
print(Fore.RED + 'This text is red')
print(Back.GREEN + 'This text has a green background')
print(Style.BRIGHT + 'This text is bright')

# Reset colors
print(Style.RESET_ALL + 'Back to normal')
# Out:
# This text is red
# This text has a green background
# This text is bright
# Back to normal
